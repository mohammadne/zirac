# %%
import random

salary_lsit = [random.randint(50_000, 100_000) for _ in range(1_000_000)]

# %%
import statistics
import numpy as np

# %%
# %%time
statistics.mean(salary_lsit) # 5.1 s
# Out:
# CPU times: user 242 ms, sys: 1.96 ms, total: 244 ms
# Wall time: 245 ms
# 74983.708617

# %%
# %%time
np.mean(salary_lsit) # 655 ms
# Out:
# CPU times: user 53.6 ms, sys: 86 μs, total: 53.6 ms
# Wall time: 53 ms
# np.float64(74983.708617)

# %%
job_titles = np.array(["AI Engineer", "SRE"])

base_salaries = np.array([60000, 80000, np.nan])
bonus_rates = np.array([0.05, 0.12, np.nan])

salaries = base_salaries * (1+bonus_rates)
print(salaries)
print(np.nanmean(salaries))
# Out:
# [63000. 89600.    nan]
# nan
# 76300.0
